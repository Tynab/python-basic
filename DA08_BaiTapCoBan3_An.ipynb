# %% [markdown]
# # Bài tập Python cơ bản 3 - Tính bảo hiểm và thuế thu nhập cá nhân
#
# Với lương và phụ cấp của từng nhân viên, chương trình tính tổng bảo hiểm (BH), thuế thu nhập cá nhân (PIT) và lương thực nhận. Các mức trần, tỷ lệ và biểu thuế bên dưới giữ nguyên giả định năm 2023 của bài làm ban đầu.

# %%
from dataclasses import dataclass
from math import inf


# Các tham số bảo hiểm theo giả định của bài.
LUONG_CO_SO = 1_800_000
LUONG_TOI_THIEU_VUNG = 4_680_000
HE_SO_TRAN_BAO_HIEM = 20
TY_LE_BHXH = 0.08
TY_LE_BHYT = 0.015
TY_LE_BHTN = 0.01

# Giảm trừ bản thân và biểu thuế lũy tiến rút gọn: cận trên, thuế suất, số trừ nhanh.
GIAM_TRU_BAN_THAN = 11_000_000
BIEU_THUE = (
    (5_000_000, 0.05, 0),
    (10_000_000, 0.10, 250_000),
    (18_000_000, 0.15, 750_000),
    (32_000_000, 0.20, 1_650_000),
    (52_000_000, 0.25, 3_250_000),
    (80_000_000, 0.30, 5_850_000),
    (inf, 0.35, 9_850_000),
)

# %%
@dataclass(frozen=True)
class NhanVien:
    """Dữ liệu đầu vào của một nhân viên."""

    ten: str
    luong: float
    phu_cap: float = 0

    def __post_init__(self):
        # Không chấp nhận giá trị âm vì lương và phụ cấp là các khoản thu nhập.
        if self.luong < 0 or self.phu_cap < 0:
            raise ValueError("Lương và phụ cấp phải là số không âm.")


@dataclass(frozen=True)
class KetQuaLuong:
    """Các khoản khấu trừ và lương thực nhận đã tính."""

    bao_hiem: float
    thue_thu_nhap: float
    luong_thuc_nhan: float

# %%
def tinh_bhxh(luong):
    """Tính BHXH với trần bằng 20 lần lương cơ sở."""
    return min(luong, LUONG_CO_SO * HE_SO_TRAN_BAO_HIEM) * TY_LE_BHXH


def tinh_bhyt(luong):
    """Tính BHYT với cùng mức trần dùng cho BHXH."""
    return min(luong, LUONG_CO_SO * HE_SO_TRAN_BAO_HIEM) * TY_LE_BHYT


def tinh_bhtn(luong):
    """Tính BHTN với trần bằng 20 lần lương tối thiểu vùng."""
    return min(luong, LUONG_TOI_THIEU_VUNG * HE_SO_TRAN_BAO_HIEM) * TY_LE_BHTN


def tinh_bao_hiem(luong):
    """Cộng ba khoản bảo hiểm người lao động phải đóng."""
    if luong < 0:
        raise ValueError("Lương phải là số không âm.")
    return tinh_bhxh(luong) + tinh_bhyt(luong) + tinh_bhtn(luong)

# %%
def tinh_thue_thu_nhap(thu_nhap_tinh_thue):
    """Tính PIT theo biểu thuế lũy tiến và công thức trừ nhanh."""
    if thu_nhap_tinh_thue <= 0:
        return 0.0

    for can_tren, thue_suat, so_tru_nhanh in BIEU_THUE:
        if thu_nhap_tinh_thue <= can_tren:
            return thu_nhap_tinh_thue * thue_suat - so_tru_nhanh

    # BIEU_THUE luôn kết thúc bằng cận vô cùng nên nhánh này chỉ để bảo vệ cấu hình.
    raise RuntimeError("Biểu thuế không bao phủ mức thu nhập đã cho.")

# %%
def tinh_luong(nhan_vien):
    """Tính BH, PIT và lương thực nhận cho một nhân viên."""
    bao_hiem = tinh_bao_hiem(nhan_vien.luong)
    tong_thu_nhap = nhan_vien.luong + nhan_vien.phu_cap
    thu_nhap_tinh_thue = max(
        0, tong_thu_nhap - bao_hiem - GIAM_TRU_BAN_THAN
    )
    thue_thu_nhap = tinh_thue_thu_nhap(thu_nhap_tinh_thue)
    luong_thuc_nhan = tong_thu_nhap - bao_hiem - thue_thu_nhap
    return KetQuaLuong(bao_hiem, thue_thu_nhap, luong_thuc_nhan)

# %%
# Dữ liệu mẫu phủ trường hợp không chịu thuế, chịu thuế bậc giữa và chịu mức cao.
DANH_SACH_NHAN_VIEN = [
    NhanVien("An", 10_000_000, 1_000_000),
    NhanVien("Bình", 20_000_000, 2_000_000),
    NhanVien("Chi", 100_000_000, 5_000_000),
]


def main(danh_sach_nhan_vien):
    """Tính và in đầy đủ kết quả cho từng nhân viên."""
    for nhan_vien in danh_sach_nhan_vien:
        ket_qua = tinh_luong(nhan_vien)
        print(f"Nhân viên: {nhan_vien.ten}")
        print(f"  Bảo hiểm (BH): {ket_qua.bao_hiem:,.0f} đồng")
        print(f"  Thuế TNCN (PIT): {ket_qua.thue_thu_nhap:,.0f} đồng")
        print(f"  Lương thực nhận: {ket_qua.luong_thuc_nhan:,.0f} đồng")


# Chạy dữ liệu mẫu để tạo output có thể tái lập.
main(DANH_SACH_NHAN_VIEN)
# Out:
# Nhân viên: An
#   Bảo hiểm (BH): 1,050,000 đồng
#   Thuế TNCN (PIT): 0 đồng
#   Lương thực nhận: 9,950,000 đồng
# Nhân viên: Bình
#   Bảo hiểm (BH): 2,100,000 đồng
#   Thuế TNCN (PIT): 640,000 đồng
#   Lương thực nhận: 19,260,000 đồng
# Nhân viên: Chi
#   Bảo hiểm (BH): 4,356,000 đồng
#   Thuế TNCN (PIT): 21,525,400 đồng
#   Lương thực nhận: 79,118,600 đồng

# %% [markdown]
# ## Tóm tắt
#
# Quy trình tính gồm bốn bước: cộng lương và phụ cấp, trừ các khoản bảo hiểm, áp dụng giảm trừ bản thân để xác định thu nhập tính thuế, sau đó tính PIT theo bậc thuế. Output hiển thị riêng BH và PIT đúng yêu cầu, đồng thời bổ sung lương thực nhận để dễ đối chiếu. Kết quả chỉ phản ánh các giả định được khai báo trong notebook, chưa tính người phụ thuộc hoặc các khoản giảm trừ khác.
